# %%
import re
import numpy as np
import time
from geopy.geocoders import Nominatim
import math
from geopy.distance import great_circle
import folium

# %%
def FindCities(filename,eclue_words):
    with open(filename, 'r', encoding='utf-8') as file:
        text = file.read()
    from_to_pattern = r'rom\s+([^:,\n]+?)\s+to\s+([A-Za-z\s]+)' # From to pattern
    from_to_matches = re.findall(from_to_pattern, text)
    
    left_reached_pattern = r'(Left|Reached)\s+([A-Za-z\s]+)' # left reached pattern
    left_reached_matches = re.findall(left_reached_pattern, text)

    city_routes = []

    for from_city, to_city in from_to_matches:
        first_word = from_city.strip().split()[0]  # Get the first word after "From"
        if first_word.lower() not in exclusion_words:
            city_routes.append((from_city.strip(), to_city.strip()))

    routes= [(action, city.strip()) for action, city in left_reached_matches] 
    filtered_routes = []
    
    for i in range(0, len(routes), 2):
        if i + 1 < len(routes):
            filtered_routes.append((routes[i][1], routes[i + 1][1].split()[0]))

    combined_routes = city_routes + filtered_routes
    
    return combined_routes

filename = '80days.txt'
special_words = ['one', 'time','the','hand','top','end','ten','right'] 
city_routes = FindCities(filename, special_words)
print(city_routes)
# Out:
# [('cellar', 'garret'), ('London', 'Suez via Mont Cenis and Brindisi'), ('Suez', 'Bombay'), ('Bombay', 'Calcutta'), ('Calcutta', 'Hong Kong'), ('Hong Kong', 'Yokohama'), ('Yokohama', 'San Francisco'), ('San Francisco', 'New York'), ('New York', 'London'), ('England', 'India by the Cape of Good Hope was\nabridged by at least a half'), ('Suez', 'Aden'), ('Suez directly', 'Bombay'), ('Bombay', 'Calcutta in three days'), ('here', 'Allahabad'), ('Bombay', 'Calcutta'), ('Kholby', 'Allahabad'), ('Calcutta', 'Hong Kong only comprised some three thousand five hundred\nmiles'), ('country', 'country'), ('Passepartout', 'his master would ruin all'), ('America', 'Europe is only a step'), ('Yokohama', 'San Francisco\nmade a direct connection with that from Hong Kong'), ('here. In going', 'Shanghai we should not be forced to sail wide of the Chinese coast'), ('England', 'the United States'), ('copper-colour', 'a dead white'), ('Hong Kong', 'Shanghai on the'), ('Yokohama', 'San Francisco\nbelonged to the Pacific Mail Steamship Company'), ('San Francisco', 'New York'), ('New York', 'Liverpool'), ('London', 'Aden'), ('Aden', 'Bombay'), ('Calcutta', 'Singapore'), ('Singapore', 'Yokohama'), ('ocean', 'ocean'), ('New York', 'San Francisco consumed'), ('Omaha. The line from San Francisco', 'Sacramento runs in a north'), ('eleven', 'twelve o'), ('thinking that it would be more natural for us', 'cross the bridge on foot'), ('him! He began', 'accuse and abuse himself'), ('Omaha', 'San Francisco was not due\ntill the next day'), ('Havre', 'Southampton would\nrender Phileas Fogg'), ('New York', 'Liverpool in the nine days'), ('New York', 'Bordeaux'), ('New York', 'Liverpool'), ('Dublin they are sent on', 'Liverpool by the most rapid boats'), ('Liverpool', 'London\nwas six hours'), ('New York', 'get here in time arrived yesterday'), ('London', 'Paris'), ('Paris', 'Turin'), ('Turin', 'Suez')]

# %%
filtered_tuples = []
for a, b in city_routes:
    a_words = [word for word in a.split() if word.istitle()]
    b_words = [word for word in b.split() if word.istitle()]
    
    if a_words and b_words:
        filtered_tuples.append((" ".join(a_words), " ".join(b_words)))

print(filtered_tuples)
# Out:
# [('London', 'Suez Mont Cenis Brindisi'), ('Suez', 'Bombay'), ('Bombay', 'Calcutta'), ('Calcutta', 'Hong Kong'), ('Hong Kong', 'Yokohama'), ('Yokohama', 'San Francisco'), ('San Francisco', 'New York'), ('New York', 'London'), ('England', 'India Cape Good Hope'), ('Suez', 'Aden'), ('Suez', 'Bombay'), ('Bombay', 'Calcutta'), ('Bombay', 'Calcutta'), ('Kholby', 'Allahabad'), ('Calcutta', 'Hong Kong'), ('America', 'Europe'), ('Yokohama', 'San Francisco Hong Kong'), ('In', 'Shanghai Chinese'), ('England', 'United States'), ('Hong Kong', 'Shanghai'), ('Yokohama', 'San Francisco Pacific Mail Steamship Company'), ('San Francisco', 'New York'), ('New York', 'Liverpool'), ('London', 'Aden'), ('Aden', 'Bombay'), ('Calcutta', 'Singapore'), ('Singapore', 'Yokohama'), ('New York', 'San Francisco'), ('Omaha. The San Francisco', 'Sacramento'), ('Omaha', 'San Francisco'), ('Havre', 'Southampton Phileas Fogg'), ('New York', 'Liverpool'), ('New York', 'Bordeaux'), ('New York', 'Liverpool'), ('Dublin', 'Liverpool'), ('Liverpool', 'London'), ('London', 'Paris'), ('Paris', 'Turin'), ('Turin', 'Suez')]

# %%
tuples_to_remove = [
    ('In', 'Shanghai Chinese'),
    ('Omaha. The San Francisco', 'Sacramento'),
    ('America', 'Europe'),
    ('Yokohama', 'San Francisco Hong Kong'),
    ('Yokohama', 'San Francisco Pacific Mail Steamship Company'),
    ('England', 'India Cape Good Hope'),
    ('England', 'United States')

]
unique_tuples = list(set(filtered_tuples))
filter_routes = [route for route in unique_tuples if route not in tuples_to_remove]
filter_routes
# Out:
# [('Bombay', 'Calcutta'),
#  ('Suez', 'Aden'),
#  ('Omaha', 'San Francisco'),
#  ('Dublin', 'Liverpool'),
#  ('Suez', 'Bombay'),
#  ('London', 'Paris'),
#  ('Turin', 'Suez'),
#  ('Paris', 'Turin'),
#  ('London', 'Aden'),
#  ('Hong Kong', 'Yokohama'),
#  ('San Francisco', 'New York'),
#  ('Singapore', 'Yokohama'),
#  ('Liverpool', 'London'),
#  ('Havre', 'Southampton Phileas Fogg'),
#  ('Aden', 'Bombay'),
#  ('London', 'Suez Mont Cenis Brindisi'),
#  ('Hong Kong', 'Shanghai'),
#  ('New York', 'Liverpool'),
#  ('New York', 'San Francisco'),
#  ('Calcutta', 'Singapore'),
#  ('Calcutta', 'Hong Kong'),
#  ('Yokohama', 'San Francisco'),
#  ('New York', 'London'),
#  ('New York', 'Bordeaux'),
#  ('Kholby', 'Allahabad')]

# %%
unique_cities = []

for route in filter_routes:
    for city in route:
        if city not in unique_cities:  
            unique_cities.append(city)

unique_cities[-5] = 'Brindisi' 
unique_cities[-6] = 'Southampton' 
print("Cities visited by Phileas Fogg:")
print(unique_cities)
# Out:
# Cities visited by Phileas Fogg:
# ['Bombay', 'Calcutta', 'Suez', 'Aden', 'Omaha', 'San Francisco', 'Dublin', 'Liverpool', 'London', 'Paris', 'Turin', 'Hong Kong', 'Yokohama', 'New York', 'Singapore', 'Havre', 'Southampton', 'Brindisi', 'Shanghai', 'Bordeaux', 'Kholby', 'Allahabad']

# %%
geolocator = Nominatim(user_agent="AroundTheWorld")
positions = dict()

for city in unique_cities:
    while True:
        try:
            position = geolocator.geocode(city)
        except Exception as e:
            print(f"Error occurred: {e}. Retrying in 5 seconds...")
            time.sleep(5)
            continue
        break
    
    if position:
        location = [position.latitude, position.longitude]
        positions.update({city: location})
        del position 
    else:
        print(f"Could not get position for {city}")

positions
# Out:
# Could not get position for Kholby
# {'Bombay': [19.08157715, 72.88662753964906],
#  'Calcutta': [22.5726459, 88.3638953],
#  'Suez': [29.974498, 32.537086],
#  'Aden': [12.789585, 45.028504],
#  'Omaha': [41.2587459, -95.9383758],
#  'San Francisco': [37.7792588, -122.4193286],
#  'Dublin': [53.3493795, -6.2605593],
#  'Liverpool': [53.4071991, -2.99168],
#  'London': [51.5074456, -0.1277653],
#  'Paris': [48.8588897, 2.3200410217200766],
#  'Turin': [45.0677551, 7.6824892],
#  'Hong Kong': [22.350627, 114.1849161],
#  'Yokohama': [35.4503381, 139.6343802],
#  'New York': [40.7127281, -74.0060152],
#  'Singapore': [1.357107, 103.8194992],
#  'Havre': [48.5536972, -109.677802],
#  'Southampton': [50.9025349, -1.404189],
#  'Brindisi': [40.63591975, 17.688443357842537],
#  'Shanghai': [31.2312707, 121.4700152],
#  'Bordeaux': [44.841225, -0.5800364],
#  'Allahabad': [25.4381302, 81.8338005]}

# %%
map_center = [20, 0]  
map_cities = folium.Map(location=map_center, zoom_start=2)

for city, coords in positions.items():
    folium.Marker(
        location=coords,
        popup=city,
        icon=folium.Icon(icon="plane",color='pink')
    ).add_to(map_cities)

map_cities
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c6a33948470daa38e68200029119b50 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c6a33948470daa38e68200029119b50&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c6a33948470daa38e68200029119b50 = L.map(
#                 &quot;map_7c6a33948470daa38e68200029119b50&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_91b0648c97c95ad342b1630bcfb40131 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_91b0648c97c95ad342b1630bcfb40131.addTo(map_7c6a33948470daa38e68200029119b50);
#
#
#             var marker_b7652a3e6e007cc0d0d2d7788c88ba0a = L.marker(
#                 [19.08157715, 72.88662753964906],
#                 {}
#             ).addTo(map_7c6a33948470daa38e68200029119b50);
#
#
#             var icon_1fd25701b640666193001514f698403e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;plane&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b7652a3e6e007cc0d0d2d7788c88ba0a.setIcon(icon_1fd25701b640666193001514f698403e);
#
#
#         var popup_89518d23b98abaa98a3002f1faff54b6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0c7c6454620088238840a5a919d5f3b8 = $(`&lt;div id=&quot;html_0c7c6454620088238840a5a919d5f3b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bombay&lt;/div&gt;`)[0];
#                 popup_89518d23b98abaa98a3002f1faff54b6.setContent(html_0c7c6454620088238840a5a919d5f3b8);
#
#
#
#         marker_b7652a3e6e007cc0d0d2d7788c88ba0a.bindPopup(popup_89518d23b98abaa98a3002f1faff54b6)
#         ;
#
#
#
#
#             var marker_e661df516475344ced2e08bb7ac8e0e0 = L.marker(
#                 [22.5726459, 88.3638953],
#                 {}
#             ).addTo(map_7c6a33948470daa38e68200029119b50);
#
#
#             var icon_d5281a7bb82c5d0ff30ad76265a36463 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;plane&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e661df516475344ced2e08bb7ac8e0e0.setIcon(icon_d5281a7bb82c5d0ff30ad76265a36463);
#
#
#         var popup_3e47e23d0e4497aa7c436d5504bb2234 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9bee2d08bf207110aa7406389be4a152 = $(`&lt;div id=&quot;html_9bee2d08bf207110aa7406389be4a152&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Calcutta&lt;/div&gt;`)[0];
#                 popup_3e47e23d0e4497aa7c436d5504bb2234.setContent(html_9bee2d08bf207110aa7406389be4a152);
#
#
#
#         marker_e661df516475344ced2e08bb7ac8e0e0.bindPopup(popup_3e47e23d0e4497aa7c436d5504bb2234)
#         ;
#
#
#
#
#             var marker_7af21ff6584b92ff21f45718a3b0b7b3 = L.marker(
#                 [29.974498, 32.537086],
#                 {}
#             ).addTo(map_7c6a33948470daa38e68200029119b50);
#
#
#             var icon_16b9b2a1a76c778da1f316d42aec79a3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;plane&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7af21ff6584b92ff21f45718a3b0b7b3.setIcon(icon_16b9b2a1a76c778da1f316d42aec79a3);
#
#
#         var popup_d9fe4030ec8a2bda5197401cf37a62bd = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0b79518b7371d11403147bb166f8bc77 = $(`&lt;div id=&quot;html_0b79518b7371d11403147bb166f8bc77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Suez&lt;/div&gt;`)[0];
#                 popup_d9fe4030ec8a2bda5197401cf37a62bd.setContent(html_0b79518b7371d11403147bb166f8bc77);
#
#
#
#         marker_7af21ff6584b92ff21f45718a3b0b7b3.bindPopup(popup_d9fe4030ec8a2bda5197401cf37a62bd)
#         ;
#
#
#
#
#             var marker_c1b6b1659bb54427f7dc965a67d25158 = L.marker(
#                 [12.789585, 45.028504],
#                 {}
#             ).addTo(map_7c6a33948470daa38e68200029119b50);
#
#
#             var icon_e4b73db95c9d15208fabf055ef34fd50 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;plane&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;pink&quot;

# %%
from geopy.distance import great_circle
import folium

starting_city = 'London'
route = [starting_city]
remaining_cities = {city: coords for city, coords in positions.items() if city != starting_city}

while remaining_cities:
    next_city = min(remaining_cities, key=lambda city: great_circle(positions[route[-1]], positions[city]).kilometers)
    route.append(next_city)
    del remaining_cities[next_city]


map_cities = folium.Map(location=[20, 0], zoom_start=2)


for index, city in enumerate(route, start=1):
    folium.Marker(
        location=positions[city],
        popup=f"{index}: {city}",
        icon=folium.DivIcon(
            html=f"""<div style="font-size: 12pt; color: black; background-color: white; 
                     border-radius: 5px; text-align: center;"><b>{index}</b></div>""")).add_to(map_cities)

folium.PolyLine(
    locations=[positions[city] for city in route], color='red', weight=2.5, opacity=1).add_to(map_cities)

map_cities
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_851ee1fd158efe16b10a7d1aac39b4b4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_851ee1fd158efe16b10a7d1aac39b4b4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_851ee1fd158efe16b10a7d1aac39b4b4 = L.map(
#                 &quot;map_851ee1fd158efe16b10a7d1aac39b4b4&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_24f4eafff4fca0465a9ec381ba788ada = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_24f4eafff4fca0465a9ec381ba788ada.addTo(map_851ee1fd158efe16b10a7d1aac39b4b4);
#
#
#             var marker_be26ea6f86298da0f073d1997205ef93 = L.marker(
#                 [51.5074456, -0.1277653],
#                 {}
#             ).addTo(map_851ee1fd158efe16b10a7d1aac39b4b4);
#
#
#             var div_icon_3d789a0fa67f41b40a87b3e96509750a = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12pt; color: black; background-color: white; \n                     border-radius: 5px; text-align: center;\&quot;\u003e\u003cb\u003e1\u003c/b\u003e\u003c/div\u003e&quot;});
#             marker_be26ea6f86298da0f073d1997205ef93.setIcon(div_icon_3d789a0fa67f41b40a87b3e96509750a);
#
#
#         var popup_f4485e69286b67d03e6287d009870c53 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5d3799498f2c3c250d1d1953ebcec08b = $(`&lt;div id=&quot;html_5d3799498f2c3c250d1d1953ebcec08b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1: London&lt;/div&gt;`)[0];
#                 popup_f4485e69286b67d03e6287d009870c53.setContent(html_5d3799498f2c3c250d1d1953ebcec08b);
#
#
#
#         marker_be26ea6f86298da0f073d1997205ef93.bindPopup(popup_f4485e69286b67d03e6287d009870c53)
#         ;
#
#
#
#
#             var marker_35d7f86cf90d51d43644a590a1a11eae = L.marker(
#                 [50.9025349, -1.404189],
#                 {}
#             ).addTo(map_851ee1fd158efe16b10a7d1aac39b4b4);
#
#
#             var div_icon_16afd3636aefefb1c8e08ac20f757770 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12pt; color: black; background-color: white; \n                     border-radius: 5px; text-align: center;\&quot;\u003e\u003cb\u003e2\u003c/b\u003e\u003c/div\u003e&quot;});
#             marker_35d7f86cf90d51d43644a590a1a11eae.setIcon(div_icon_16afd3636aefefb1c8e08ac20f757770);
#
#
#         var popup_1b1917f9483cdb9ecaefb387c167f51a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5b3a2220c289ab02d76eaf900209d764 = $(`&lt;div id=&quot;html_5b3a2220c289ab02d76eaf900209d764&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2: Southampton&lt;/div&gt;`)[0];
#                 popup_1b1917f9483cdb9ecaefb387c167f51a.setContent(html_5b3a2220c289ab02d76eaf900209d764);
#
#
#
#         marker_35d7f86cf90d51d43644a590a1a11eae.bindPopup(popup_1b1917f9483cdb9ecaefb387c167f51a)
#         ;
#
#
#
#
#             var marker_e5920678dfe0f4d5a407a9c1918da1e0 = L.marker(
#                 [53.4071991, -2.99168],
#                 {}
#             ).addTo(map_851ee1fd158efe16b10a7d1aac39b4b4);
#
#
#             var div_icon_a2f87954df7b07c58cf482f378609ade = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12pt; color: black; background-color: white; \n                     border-radius: 5px; text-align: center;\&quot;\u003e\u003cb\u003e3\u003c/b\u003e\u003c/div\u003e&quot;});
#             marker_e5920678dfe0f4d5a407a9c1918da1e0.setIcon(div_icon_a2f87954df7b07c58cf482f378609ade);
#
#
#         var popup_1fecb3815cef711ae99f84f6a506ba00 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_632ffbc8ce9c7c7fdcbdc726668a00e2 = $(`&lt;div id=&quot;html_632ffbc8ce9c7c7fdcbdc726668a00e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3: Liverpool&lt;/div&gt;`)[0];
#                 popup_1fecb3815cef711ae99f84f6a506ba00.setContent(html_632ffbc8ce9c7c7fdcbdc726668a00e2);
#
#
#
#         marker_e5920678dfe0f4d5a407a9c1918da1e0.bindPopup(popup_1fecb3815cef711ae99f84f6a506ba00)
#         ;
#
#
#
#
#             var marker_3950aa71188e4706b715d3318c05cabc = L.marker(
#                 [53.3493795, -6.2605593],
#                 {}
#             ).addTo(map_851ee1fd158efe16b10a7d1aac39b4b4);
#
#
#             var div_icon_f57a072037552df7943d3b0a08085fb3 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;font-size: 12pt; color: black;

# %%
starting_city = 'London'
remaining_cities = {k: v for k, v in positions.items() if k != starting_city}

dublin_coords = remaining_cities.pop('Dublin', None)
liverpool_coords = remaining_cities.pop('Liverpool', None)

route = [starting_city]
while remaining_cities:
    next_city = find_closest_city(route[-1], remaining_cities)
    route.append(next_city)
    del remaining_cities[next_city]

if dublin_coords:
    route.append('Dublin')
if liverpool_coords:
    route.append('Liverpool')


map_center = [20, 0]
map_cities = folium.Map(location=map_center, zoom_start=2)

for index, city in enumerate(route, start=1): 
    folium.Marker(
        location=positions[city],
        popup=f"{index}: {city}", 
        icon=folium.DivIcon(
            html=f"""
                <div style="background-color: darkgreen; border-radius: 50%; width: 20px; height: 20px; display: flex; align-items: center; justify-content: center; color: white; font-weight: bold; font-size: 11pt;">
                    {index}
                </div>
            """
        )
    ).add_to(map_cities)

coords_list = [positions[city] for city in route]
folium.PolyLine(
    locations=coords_list,
    color='green',
    weight=2.5,
    opacity=1
).add_to(map_cities)

map_cities
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b909b4e68727170c726ba7943e4e99ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b909b4e68727170c726ba7943e4e99ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b909b4e68727170c726ba7943e4e99ac = L.map(
#                 &quot;map_b909b4e68727170c726ba7943e4e99ac&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4079028314ca09568f69d73d2e9a870f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4079028314ca09568f69d73d2e9a870f.addTo(map_b909b4e68727170c726ba7943e4e99ac);
#
#
#             var marker_261218f7c0590268b97e4446cb600cdf = L.marker(
#                 [51.5074456, -0.1277653],
#                 {}
#             ).addTo(map_b909b4e68727170c726ba7943e4e99ac);
#
#
#             var div_icon_6b46d470d25a30351b7cb4d0cd8b0c1b = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;background-color: darkgreen; border-radius: 50%; width: 20px; height: 20px; display: flex; align-items: center; justify-content: center; color: white; font-weight: bold; font-size: 11pt;\&quot;\u003e\n                    1\n                \u003c/div\u003e\n            &quot;});
#             marker_261218f7c0590268b97e4446cb600cdf.setIcon(div_icon_6b46d470d25a30351b7cb4d0cd8b0c1b);
#
#
#         var popup_8cf668df26a16b5c158ba06bd5b16d06 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6cab58c2853178d7360de37d6cdc5c8e = $(`&lt;div id=&quot;html_6cab58c2853178d7360de37d6cdc5c8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1: London&lt;/div&gt;`)[0];
#                 popup_8cf668df26a16b5c158ba06bd5b16d06.setContent(html_6cab58c2853178d7360de37d6cdc5c8e);
#
#
#
#         marker_261218f7c0590268b97e4446cb600cdf.bindPopup(popup_8cf668df26a16b5c158ba06bd5b16d06)
#         ;
#
#
#
#
#             var marker_bb23e8874af6532d3445bd6aafc1bafd = L.marker(
#                 [50.9025349, -1.404189],
#                 {}
#             ).addTo(map_b909b4e68727170c726ba7943e4e99ac);
#
#
#             var div_icon_ad7611ced877c15f1b5d69b09f013a0d = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;background-color: darkgreen; border-radius: 50%; width: 20px; height: 20px; display: flex; align-items: center; justify-content: center; color: white; font-weight: bold; font-size: 11pt;\&quot;\u003e\n                    2\n                \u003c/div\u003e\n            &quot;});
#             marker_bb23e8874af6532d3445bd6aafc1bafd.setIcon(div_icon_ad7611ced877c15f1b5d69b09f013a0d);
#
#
#         var popup_787d216a3f80e2cb488bd9cf76df0dff = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_771755aaf00c53e3b96a226952dfbfb6 = $(`&lt;div id=&quot;html_771755aaf00c53e3b96a226952dfbfb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;2: Southampton&lt;/div&gt;`)[0];
#                 popup_787d216a3f80e2cb488bd9cf76df0dff.setContent(html_771755aaf00c53e3b96a226952dfbfb6);
#
#
#
#         marker_bb23e8874af6532d3445bd6aafc1bafd.bindPopup(popup_787d216a3f80e2cb488bd9cf76df0dff)
#         ;
#
#
#
#
#             var marker_32aedb394d5dad6bfff33bdb11f832fa = L.marker(
#                 [48.8588897, 2.3200410217200766],
#                 {}
#             ).addTo(map_b909b4e68727170c726ba7943e4e99ac);
#
#
#             var div_icon_e7e5ab5ddd3b257d83a63ba915df329d = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\n                \u003cdiv style=\&quot;background-color: darkgreen; border-radius: 50%; width: 20px; height: 20px; display: flex; align-items: center; justify-content: center; color: white; font-weight: bold; font-size: 11pt;\&quot;\u003e\n                    3\n                \u003c/div\u003e\n            &quot;});
#             marker_32aedb394d5dad6bfff33bdb11f832fa.setIcon(div_icon_e7e5ab5ddd3b257d83a63ba915df329d);
#
#
#         var popup_1b70fc9c16f4faf001d76c4824e49d8c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_372e7f073c72c73df6a023ab069fa538 = $(`&lt;div id=&quot;html_372e7f073c72c73df6a023ab069fa538&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;3: Paris&lt;/div&gt;`)[0];
#                 popup_1b70fc9c16f4faf001d76c4824e49d8c.setContent(html_372e7f073c72c73df6a023ab069fa538);
#
#
#
#         marker_32aedb394d5dad6bfff33bdb11f832fa.bindPopup(popup_1b70fc9c16f4faf001d76c4824e49d8c)
#         ;
#
#
#
#
#             var marker_cbb92308e546787315951f863
